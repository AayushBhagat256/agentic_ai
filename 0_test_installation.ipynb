# %%
from langgraph.graph import StateGraph
# Out:
# c:\Users\Aayush Bhagat\Desktop\agentic_ai\venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
